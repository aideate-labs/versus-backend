# %%
from openai import OpenAI
import pprint

OPENAI_ORG_KEY = 'org-CJBqTlt7yBaKH17EzphQivGs'
#OPENAI_API_KEY = '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'
OPENAI_API_KEY = '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'
client = OpenAI(api_key = OPENAI_API_KEY , organization = OPENAI_ORG_KEY)
#model="gpt-4-1106-preview",

# %% [raw]
# completion = client.chat.completions.create(
#   model="gpt-4",
#   messages=[
#     {"role": "system", "content": "You are a personal assistant and a product expert. You wont be provided any documents for retrieval. Your job is to fetch the latest data from the internet and present the comparisons of the product in a tabular format."},
#     {"role": "user", "content": "Compare dishwashers 2023"}
#     ]
# )
#
# print(completion.choices[0].message)

# %%
import os
import asyncio
import requests
import time
import json
import openai
import keyboard

from urllib.parse import quote_plus
from openai import OpenAI
from dotenv import load_dotenv
from azure.cognitiveservices.search.websearch import WebSearchClient
from azure.cognitiveservices.search.websearch.models import SafeSearch
from msrest.authentication import CognitiveServicesCredentials

# %% [raw]
# !pip3 install python-dotenv
# !pip3 install azure
# !pip3 install azure-cognitiveservices-search-websearch
# !pip3 install keyboard

# %%
# NOTE: Bing search is free for 1000 queries per month!
# NOTE: OpenAI is *not cheap* particularly using assisistants - just keep in mind!
#       GPT-4 Turbo (gpt-4-1106-preview) is set here, but you can use GPT-3.5 Turbo (gpt-3.5-turbo-1106) which is 10x cheaper

# Implementation Overview:
# - Creates an OpenAI assistant instance set up to call Bing-search and analysis functions (funcs defined in this script)
# - Uses Bing Search API to conduct internet searches based on the processed user query. NOTE: Can easily be swapped to use the Bing Custom Search service (aka resource) instead (which allows you to define what sites it can search, and what sites it can't search)

# Bing API & Service (resource) Setup:
# 1. Sign Up for Azure
#   - If you don't already have one, create a Microsoft Azure account at Azure Portal.
# 2. Go to the Azure Marketplace within the Azure Portal
# 3. Create a new Bing Search resource 
#   - If you wish to limit the search window to certain URLs or domains, then see comments listing 'Bing Custom Search' below.
# 4. Copy the API key from the Azure Portal

# Overview of the Process:
# 1: User Request: 
#   - The user provides a plain-english request for information (e.g. "What are the best stonks to buy right now?").
# 2. Automated Bing Web-Search: 
#   - OpenAI assistant generates a query to search Bing
#   - Implements the Bing Web Search API to conduct internet searches based on the processed user query.
#   - If the user request isn't clear enough to form a Bing-search query from (example query: "sup man?"), then the assistant will (likely) respond seeking more information.
# 3. Automated Search Result Processing: 
#   - Analyzes and processes the search results obtained from Bing, again using the OpenAI assistant instance.
#   - The assistant will then provide a summary of the search results, tailored to answer the user's initial query.
# Result Analysis and Response: Provides a summary or analysis of the search results, tailored to answer the user's initial query.

# NOTE (references and notes)
#  
# Bing web search (Azure) API (Use Azure marketplace and search for "Bing Search" or "Bing Custom Search" - avoid the old Bing API)
#   CURRENT AZURE API REF: https://docs.microsoft.com/en-us/azure/cognitive-services/bing-web-search/quickstarts/python
#   DEPRECATED API REF: https://learn.microsoft.com/en-us/bing/search-apis/bing-web-search/quickstarts/sdk/web-search-client-library-python
# 
# Tavily web-search for LLMs (alternative option - probably not as good as Bing search)
#   https://docs.tavily.com/docs/tavily-api/python-sdk
#
# OpenAI Tools (assistants):
#   https://platform.openai.com/docs/assistants/tools
#   https://platform.openai.com/docs/assistants/tools/function-calling
#   RECENT: https://medium.com/@nilakashdas/how-to-build-smart-assistants-using-open-ai-apis-ebf9edc42084 
#   https://medium.com/@assafelovic/how-to-build-an-openai-assistant-with-internet-browsing-ee5ad7625661
#   NOTE, share results with community:
#   https://community.openai.com/t/new-assistants-browse-with-bing-ability/479383/12
#   Multi-function assistants:
#   https://dev.to/esponges/build-the-new-openai-assistant-with-function-calling-52f5
# 
# Use a connection to Azure OpenAI on your data.
#   https://learn.microsoft.com/en-us/microsoft-copilot-studio/nlu-generative-answers-azure-openai

# TODO: 
#   Have LLM scrape data from sites linked by the Bing web search, and then analyze the *scraped data* (rather than raw search results) to answer the user's question.
#   Consider using local LLM for generating Bing search query (it creates an optimized keyword search query from user's plain english request) 
#   Consider using local LLM for performing Bing search analysis (for answering user's question)

# %%
############################################################################################################
### CONFIGURATIONS 
############################################################################################################

# Load environment variables
load_dotenv()

# OpenAI API Key
#client = OpenAI(api_key=os.environ["OPENAI_API_KEY"]) #commented
client = OpenAI(api_key = OPENAI_API_KEY , organization = OPENAI_ORG_KEY)

# NOTE: OLD BING API fields
# subscription_key = "79f43664b4a343e38b4017f758ee80f3"
# search_client = WebSearchClient(endpoint="https://api.bing.microsoft.com/", credentials=CognitiveServicesCredentials(subscription_key))

# NOTE: NEW BING API fields (API migrated to azure marketplace)
# custom_config_id = "define this if you are using 'Bing Custom Search' service (aka resource) instead of 'Bing Search'"
searchTerm = "microsoft"
# NOTE: This URL is not the same as the one listed in the Azure resource portal. It has the additional v7.0/search? to specify the resource function.
url = 'https://api.bing.microsoft.com/v7.0/search?' #  + 'q=' + searchTerm + '&' + 'customconfig=' + custom_config_id

# OpenAI Model Configuration
base_model = "gpt-4-1106-preview"
max_tokens = 7000 
temperature = 0.2

u_request = ""
s_query = ""
s_results = ""
run = None

# %%
############################################################################################################
### OPENAI FUNCTIONS: Functions to perform a Bing search and process the results
############################################################################################################

# OPENAI FUNCTION: Function to perform a Bing search
def perform_bing_search(user_request):
  global u_request
  global s_query
  global s_results

  u_request = user_request
  print(f"\n### Generating a search_query for bing based on this user request: {user_request}")
  openai_prompt = "Generate a search-engine query to satisfy this user's request: " + user_request
  response = client.chat.completions.create(
      model=base_model,
      messages=[{"role": "user", "content": openai_prompt}],
  )
  # Get the response from OpenAI
  bing_query = response.model_dump_json(indent=2)
  s_query = bing_query
  print(f"\n### Bing search query: {bing_query}. Now executing the search...")
  
  bing_response = run_bing_search(user_request)
  s_results = bing_response
  return bing_response
    

# OPENAI FUNCTION: Function to process Bing search results
def process_search_results(search_results):
  global u_request
  global s_query
  global s_results

  print(f"\n#### Analyzing/processing Bing search results")

  # Use GPT to analyze the Bing search results
  prompt = f"Analyze these Bing search results: '{s_results}'\nbased on this user request: {u_request}"
  
  response = client.chat.completions.create(
      model=base_model,
      messages=[{"role": "user", "content": prompt}],
  )
  analysis =  response.choices[0].message.content.strip()

  print(f"\n#### Analysis: {analysis}")
  # Return the analysis
  return analysis



############################################################################################################
### ANALYSIS: Perform a Bing search and process the results
############################################################################################################

def run_bing_search(search_query):
  # Returns data of type SearchResponse 
  # https://learn.microsoft.com/en-us/python/api/azure-cognitiveservices-search-websearch/azure.cognitiveservices.search.websearch.models.searchresponse?view=azure-python
    try:
        subscription_key = "c220d4739b45466eb1d02b5fccdeaa39"
        base_url = "https://api.bing.microsoft.com/v7.0/search?"
        encoded_query = quote_plus(search_query)
        bing_search_query = base_url + 'q=' + encoded_query # + '&' + 'customconfig=' + custom_config_id --> uncomment this if you are using 'Bing Custom Search'
        r = requests.get(bing_search_query, headers={'Ocp-Apim-Subscription-Key': subscription_key})
    except Exception as err:
        print("\n####  Encountered exception. {}".format(err))
        raise err
  
  # Old API
  #try:
  #  web_data = search_client.web.search(query=search_query)
  #except Exception as err:
  #  print("Encountered exception. {}".format(err))
  #  raise err

    response_data = json.loads(r.text)
    results_text = ""
    for result in response_data.get("webPages", {}).get("value", []):
        results_text += result["name"] + "\n"
        results_text += result["url"] + "\n"
        results_text += result["snippet"] + "\n\n"
        print(f"Title: {result['name']}")
        print(f"URL: {result['url']}")
        print(f"Snippet: {result['snippet']}\n")
        
    return results_text

# %%
############################################################################################################
### OPENAI ASSISTANT RUN MANAGEMENT
############################################################################################################

# Function to wait for a run to complete
def wait_for_run_completion(thread_id, run_id):
    while True:
        time.sleep(2)
        run = client.beta.threads.runs.retrieve(thread_id=thread_id, run_id=run_id)
        print(f"Current run status: {run.status}")
        if run.status in ['completed', 'failed', 'requires_action']:
            return run

# Function to handle tool output submission
def submit_tool_outputs(thread_id, run_id, tools_to_call, run, tool_output_array=None, func_override=None):
    global s_results
    print(f"\n#### Submitting tool outputs for thread_id: {thread_id}, run_id: {run_id}, tools_to_call: {tools_to_call}")
    if tool_output_array == None:
      tool_output_array = []
    for tool in tools_to_call:
        output = None
        tool_call_id = tool.id
        function_name = func_override if func_override else tool.function.name
        function_args = tool.function.arguments

        if function_name == "perform_bing_search":
            print("\n####[FUNCTION CALL #1] perform_bing_search()...")
            output = perform_bing_search(user_request = json.loads(function_args)["user_request"])

        elif function_name == "process_search_results":
            print("\n####[FUNCTION CALL #2] process_search_results()...")
            output = process_search_results(json.loads(function_args)["search_results"]) #search_results = s_results) #json.loads(function_args)["search_results"]) #(search_results = s_results) 

        if output:
          print("\n####[FUNCTION RESULT] Appending tool output array...")
          tool_output_array.append({"tool_call_id": tool_call_id, "output": output})

    return client.beta.threads.runs.submit_tool_outputs(
        thread_id=thread_id,
        run_id=run_id,
        tool_outputs=tool_output_array
    )


# Function to print messages from a thread
def print_messages_from_thread(thread_id):
    messages = client.beta.threads.messages.list(thread_id=thread_id)
    message = ""
    print("\n=========== ASSISTANT RESPONSE ==========\n")
    for msg in messages:
      if msg.role == "assistant":
        print(f"{msg.role}: {msg.content[0].text.value}")
        message += f"{msg.role}: {msg.content[0].text.value}\n"
    
    return message

# Initialize the assistant and its features and tools
assistant = client.beta.assistants.create(
  instructions="""You are a Q&A bot who performs web searches to respond to user queries. 
  Call function 'perform_bing_search' when provided a user query.
  Call function 'process_search_results' if the search results contain the info needed to answer the user query.
  Call function 'perform_bing_search' again if the search results do not contain the info needed to answer the user query.
  """,
  model=base_model,
  tools=[
    {
      "type": "code_interpreter"

    },
    {
    "type": "function",
    "function": {
      "name": "perform_bing_search", # Function itself should run a GPT OpenAI-query that asks the OpenAI to generate (and return) a Bing-search-query.
      "description": "Determine a Bing search query from the user_request for specified information and execute the search",
      "parameters": {
        "type": "object",
        "properties": {
          "user_request": {"type": "string", "description": "The user's request, used to formulate a Bing search message"},
        },
        "required": ["user_request"]
      }
    }
  }, 
  {
    "type": "function",
    "function": {
        "name": "process_search_results", # Function itself should send the Bing search results to openai to assess the results, and then return the results of that assessment to the user.
        #"description": "Compare top products in the US and provide recommendations",
        #"description": "Analyze Bing search results and return a summary of the results that most effectively answer the user's request",
        "description": "Analyze Bing search results and return a summary of the results in a tabular form with products as columns and comparison factors as rows",
        "parameters": {
            "type": "object",
            "properties": {
                "search_results": {"type": "string", "description": "The results from the Bing search to analyze"},
            },
            "required": ["search_results"]
        }
    } 
  }
]
)
assistant_id = assistant.id
print(f"Assistant ID: {assistant_id}")


# Create a thread
thread = client.beta.threads.create()
print(f"Thread: {thread}")
# Out:
# Assistant ID: asst_4Z4bDzOH67ycRcZu4DweQGIN
# Thread: Thread(id='thread_A0leTZTUdMbn6AUE0KsXXS5u', created_at=1705644622, metadata={}, object='thread')

# %%
# Ongoing conversation loop
while True:
      
    prompt = input("\nYour request: ")
    if prompt.lower() == 'exit':
        print("Exiting conversation")
        break

    status = "na"
    
    #while status != "completed":
      # Create a message and run
    message = client.beta.threads.messages.create(
        thread_id=thread.id,
        role="user",
        content=prompt,
    )
    run = client.beta.threads.runs.create(
        thread_id=thread.id,
        assistant_id=assistant_id,   
    )
    print(f"Run ID: {run.id}")
    # Wait for run to complete
    
    run = wait_for_run_completion(thread.id, run.id)
    while run.status == 'requires_action':
        print("Run requires action 1")
        run = submit_tool_outputs(thread.id, run.id, run.required_action.submit_tool_outputs.tool_calls, run) # **error on this line**
        run = wait_for_run_completion(thread.id, run.id)

        time.sleep(1)
    if run.status == 'failed':
        print(run.error)
        continue
    # Print messages from the thread
    #prompt = print_messages_from_thread(thread.id)
    print_messages_from_thread(thread.id)
    time.sleep(1)
# Out:
# Your request:  dishwashers US 2024
# Run ID: run_aVGUWB1bx29ZSJb6BwJMSF1r
# Current run status: in_progress
# Current run status: requires_action
# Run requires action 1
#
# #### Submitting tool outputs for thread_id: thread_A0leTZTUdMbn6AUE0KsXXS5u, run_id: run_aVGUWB1bx29ZSJb6BwJMSF1r, tools_to_call: [RequiredActionFunctionToolCall(id='call_grnFynB3527rXZXg6PpRwbrk', function=Function(arguments='{"user_request":"dishwashers US 2024"}', name='perform_bing_search'), type='function')]
#
# ####[FUNCTION CALL #1] perform_bing_search()...
#
# ### Generating a search_query for bing based on this user request: dishwashers US 2024
#
# ### Bing search query: {
#   "id": "chatcmpl-8icNGqZq6tPhnpGpBFvEjHRpgUSWl",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "message": {
#         "content": "\"Best dishwashers in US 2024\"",
#         "role": "assistant",
#         "function_call": null,
#         "tool_calls": null
#       },
#       "logprobs": null
#     }
#   ],
#   "created": 1705644634,
#   "model": "gpt-4-1106-preview",
#   "object": "chat.completion",
#   "system_fingerprint": "fp_04de91a479",
#   "usage": {
#     "completion_tokens": 11,
#     "prompt_tokens": 26,
#     "total_tokens": 37
#   }
# }. Now executing the search...
# Title: Best dishwashers in 2024 | Tom's Guide
# URL: https://www.tomsguide.com/us/best-dishwashers,review-6292.html
# Snippet: Best dishwashers in 2024 By Katie Mortram last updated 8 December 2023 The best dishwashers for every family size and budget. Comments (0) Jump to: Quick list Best overall Best value Best...
#
# Title: Best Dishwashers of 2024 - Consumer Reports
# URL: https://www.consumerreports.org/appliances/dishwashers/best-dishwashers-of-the-year-a6109623431/
# Snippet: Best Dishwashers of 2024 Standouts from our testing include models from Bosch, Ikea, and other top brands By Molly Bradley, Liam McCabe Updated by Daniel Bortz Updated January 1, 2024 59 When...
#
# Title: The 3 Best Dishwashers of 2024 | Reviews by Wirecutter - The New York Times
# URL: https://www.nytimes.com/wirecutter/reviews/the-best-dishwasher/
# Snippet: The Best Dishwashers. Our top pick, the Bosch 300 Series SHEM63W55N, has been discontinued and replaced with the Bosch 300 Series SHE53C85N. We continue to recommend the SHEM63W55N for as long as ...
#
# Title: Best Dishwashers 2024 - Forbes Vetted
# URL: https://www.forbes.com/sites/forbes-personal-shopper/article/best-dishwashers/
# Snippet: Forbes Vetted Dec 5, 2023,02:43pm EST Share to Facebook Share to Twitter Share to Linkedin Today’s best dishwashers can do more than just lift food residue from your dinnerware.
#
# Title: 12 Best Dishwashers of 2024 - Reviewed
# URL: https://reviewed.usatoday.com/dishwashers/best-right-now/best-dishwashers
# Snippet: Best Overall Bosch SHP78CM5N 4.7 Check Price at Best Buy The Bosch 800 Series SHP78CM5N is a near-perfect dishwasher. It scrubbed out every stain we threw at it, in record time, and has great...
#
# Title: 6 Best Dishwashers of 2024, Tested & Reviewed by Experts
# URL: https://www.goodhousekeeping.com/appliances/dishwasher-reviews/g1513/best-dishwasher-reviews/
# Snippet: 6 Best Dishwashers of 2024, Tested by Cleaning Experts Wash, rinse, dry and done! Nothing for you to do but load and unload. By Carolyn Forté Updated: Aug 9, 2023 Jump to Products Save Article...
#
# Title: Best Dishwasher of 2024 - CNET
# URL: https://www.cnet.com/home/kitchen-and-household/best-dishwasher/
# Snippet: Here are our top picks for the best dishwashers of 2024 from highest value to effective, modern and best upgrade. Updated Jan. 1, 2024 12:00 p.m. PT Written by Pamela Vachon Our expert,...
#
# Title: The 10 Best Dishwashers of 2024 - The Spruce
# URL: https://www.thespruce.com/best-dishwashers-4109539
# Snippet: Most portable dishwashers are mounted on caster wheels, allowing you to easily move and stash them away in a closet when not in use. The GE GPT225SSLSS 24 in. Portable Dishwasher, our Best Portable pick, is set on caster wheels and has the look of a built-in dishwasher, without requiring under-counter space.
#
#
# ####[FUNCTION RESULT] Appending tool output array...
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: completed
#
# =========== ASSISTANT RESPONSE ==========
#
# assistant: Here is a summary of the search results for the best dishwashers in the US for the year 2024:
#
# 1. Tom's Guide published an article listing the best dishwashers for every family size and budget.
# 2. Consumer Reports highlighted standouts from their testing, including models from Bosch, Ikea, and other top brands.
# 3. The New York Times' Wirecutter has a review for the best dishwashers but notes that their top pick, the Bosch 300 Series SHEM63W55N, has been discontinued and replaced.
# 4. Forbes Vetted provides a list of what they consider today's best dishwashers that can lift food residue from your dinnerware.
# 5. Reviewed named the Bosch 800 Series SHP78CM5N as the Best Overall dishwasher.
# 6. Good Housekeeping tested and reviewed the 6 best dishwashers of 2024, emphasizing ease of use.
# 7. CNET offers their top picks for the best dishwashers of 2024, categorizing them by deepest value to modern and best upgrade.
# 8. The Spruce mentions the GE GPT225SSLSS 24 in. Portable Dishwasher as the Best Portable pick.
#
# For details on specific dishwasher models and their features, you may want to click through to these articles. If you need a comparison or more specific information, let me know!
# Your request:  need comparison of products
# Run ID: run_FKjFy5oTE9nPhIiyGs6RJUch
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: requires_action
# Run requires action 1
#
# #### Submitting tool outputs for thread_id: thread_A0leTZTUdMbn6AUE0KsXXS5u, run_id: run_FKjFy5oTE9nPhIiyGs6RJUch, tools_to_call: [RequiredActionFunctionToolCall(id='call_qlwHvoxLA9cFrqaJuRyJxZwf', function=Function(arguments='{"search_results":"Best dishwashers in 2024 | Tom\'s Guide\\nhttps://www.tomsguide.com/us/best-dishwashers,review-6292.html\\nBest dishwashers in 2024 By Katie Mortram last updated 8 December 2023 The best dishwashers for every family size and budget. Comments (0) Jump to: Quick list Best overall Best value Best...\\n\\nBest Dishwashers of 2024 - Consumer Re
#
# 3. **Wirecutter - The New York Times** (https://www.nytimes.com/wirecutter/reviews/the-best-dishwasher/)
#    - This guide states that their previous top pick, the Bosch 300 Series SHEM63W55N, has been discontinued.
#    - They recommend a replacement model and continue to endorse the earlier model as long as it remains available.
#    - However, the specific URL provided does not match the usual Wirecutter URL format and could either be an error or an outdated link as the title suggests they will review three top dishwashers without specifying.
#
# 4. **Forbes Vetted** (https://www.forbes.com/sites/forbes-personal-shopper/article/best-dishwashers/)
#    - This article from Forbes seems to emphasize the capabilities of modern dishwashers.
#    - It was published on December 5, 2023, and may provide reviews or insights into special features offered by the latest dishwashers.
#
# 5. **Reviewed** (https://reviewed.usatoday.com/dishwashers/best-right-now/best-dishwashers)
#    - The Bosch 800 Series SHP78CM5N is highlighted as the best overall dishwasher with high scores.
#    - The review indicates that it has performed well in stain removal tests.
#
# 6. **Good Housekeeping** (https://www.goodhousekeeping.com/appliances/dishwasher-reviews/g1513/best-dishwasher-reviews/)
#    - This list is compiled after testing dishwashers and is aimed at cleaning experts.
#    - It was last updated on August 9, 2023, and includes a saving article feature for later reference.
#
# 7. **CNET** (https://www.cnet.com/home/kitchen-and-household/best-dishwasher/)
#    - The dishwashers on this list are categorized by value, effectiveness, modernity, and the best upgrade.
#    - The content was updated on January 1, 2024, and authored by Pamela Vachon who is listed as an expert.
#
# 8. **The Spruce** (https://www.thespruce.com/best-dishwashers-4109539)
#    - This guide includes portable dishwashers such as the GE GPT225SSLSS which has been noted as the best pick for a portable dishwasher.
#    - There is also mention of other top models, suggesting that the list is diversified to meet different needs and preferences.
#
# In analyzing these results, it is important to note that these articles may provide rankings based on various factors such as cleaning performance, features, reliability, noise level, energy efficiency, and value for money. They seem to agree that Bosch dishwashers are among the top contenders. However, it would be advisable for a user to read the specific articles to understand the testing methodology, review criteria, and to access the most current information since models and rankings can change. Additionally, the credibility of these sources is generally high; organizations like Consumer Reports and Wirecutter are known for their thorough testing and unbiased reporting.
#
# ####[FUNCTION RESULT] Appending tool output array...
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: completed
#
# =========== ASSISTANT RESPONSE ==========
#
# assistant: Unfortunately, the current search results don't directly provide a comparative table or structured comparison between different products. Each source listed in the search results reviews and ranks dishwashers based on their own criteria, which includes testing, features, value for money, and more. To obtain a comparison of products, further analysis and synthesis of these sources' content would be needed.
#
# For a detailed product comparison, one would have to visit each website individually, compare the top dishwashers recommended by each source, and collate the information into a comparative format, taking note of any overlap or consensus between the lists. This would provide insight into which dishwasher models are consistently rated highly across different sources.
#
# If you would like, I can attempt to provide a more structured product comparison by visiting each site and compiling the information into a coherent table. However, this would be a manually intensive task requiring more in-depth review of each source's content. Let me know if you wish to proceed with this or have any other specific requests!
# assistant: Here is a summary of the search results for the best dishwashers in the US for the year 2024:
#
# 1. Tom's Guide published an article listing the best dishwashers for every family size and budget.
# 2. Consumer Reports highlighted standouts from their testing, including models from Bosch, Ikea, and other top brands.
# 3. The New York Times' Wirecutter has a review for the best dishwashers but notes that their top pick, the Bosch 300 Series SHEM63W55N, has been discontinued and replaced.
# 4. Forbes Vetted provides a list of what they consider today's best dishwashers that can lift food residue from your dinnerware.
# 5. Reviewed named the Bosch 800 Series SHP78CM5N as the Best Overall dishwasher.
# 6. Good Housekeeping tested and reviewed the 6 best dishwashers of 2024, emphasizing ease of use.
# 7. CNET offers their top picks for the best dishwashers of 2024, categorizing them by deepest value to modern and best upgrade.
# 8. The Spruce mentions the GE GPT225SSLSS 24 in. Portable Dishwasher as the Best Portable pick.
#
# For details on specific dishwasher models and their features, you may want to click through to these articles. If you need a comparison or more specific information, let me know!
# Your request:  show comparison of specific dishwashers in a table
# Run ID: run_eKpg1x5WlFHVlEfxLlSVkqw3
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: requires_action
# Run requires action 1
#
# #### Submitting tool outputs for thread_id: thread_A0leTZTUdMbn6AUE0KsXXS5u, run_id: run_eKpg1x5WlFHVlEfxLlSVkqw3, tools_to_call: [RequiredActionFunctionToolCall(id='call_Ld8Zo5HnHgWidyaKH9HyidUK', function=Function(arguments='{"search_results":"Best dishwashers in 2024 | Tom\'s Guide\\nhttps://www.tomsguide.com/us/best-dishwashers,review-6292.html\\nBest dishwashers in 2024 By Katie Mortram last updated 8 December 2023 The best dishwashers for every family size and budget. Comments (0) Jump to: Quick list Best overall Best value Best...\\n\\nBest Dishwashers of 2024 - Consumer Reports\\nhttps://www.consumerreports.org/appliances/dishwashers/best-dishwashers-of-the-year-a6109623431/\\nBest Dishwashers of 2024 Standouts from our testing include models from Bosch, Ikea, and other top brands By Molly Bradley, Liam McCabe Updated by Daniel Bortz Updated January 1, 2024 59 When...\\n\\nThe 3 Best Dishwashers of 2024 | Reviews by Wirecutter - The New York Times\\nhttps://www.nytimes.com/wirecutter/reviews/the-best-dishwasher/\\nThe Best Dishwashers. Our top pick, the Bosch 300 Series SHEM63W55N, has been discontinued and replaced with the Bosch 300 Series SHE53C85N. We continue to recommend the SHEM63W55N for as long as ...\\n\\nBest Dishwashers 2024 - Forbes Vetted\\nhttps://www.forbes.com/sites/forbes-personal-shopper/article/best-dishwashers/\\nForbes Vetted Dec 5, 2023,02:43pm EST Share to Facebook Share to Twitter Share to Linkedin Today’s best dishwashers can do more than just lift food residue from your dinnerware.\\n\\n12 Best Dishwashers of 2024 - Re
#
# 7. **CNET**
#    - URL: https://www.cnet.com/home/kitchen-and-household/best-dishwasher/
#    - Summary: CNET presents picks for the best dishwashers of 2024, ranging from highest value to models that offer modern features and upgrades. This content was refreshed on January 1, 2024.
#
# 8. **The Spruce**
#    - URL: https://www.thespruce.com/best-dishwashers-4109539
#    - Summary: This piece focuses on the portability of dishwashers, with a specific mention of a GE portable model. It gives options for those who might have space constraints or require mobility.
#
# **Analysis:**
# - Most of these websites are reputable sources for product reviews and consumer advice, such as Tom's Guide, Consumer Reports, Wirecutter (part of The New York Times), Forbes, Good Housekeeping, and CNET.
# - The articles are current as of late 2023 or the beginning of 2024, ensuring that the recommendations are recent and relevant.
# - Bosch is a brand that's mentioned multiple times across different sources, particularly its 300 and 800 series, indicating that it is likely a top-performing brand.
# - The emphasis on various features (efficiency, value, testing by experts, modern features) suggests that these articles cater to a wide range of consumer priorities.
# - The articles appear to be doing thorough testing and updating their content regularly; this is especially important for reviews since models can be discontinued and replaced by manufacturers frequently.
#
# In summary, these search results provide a diverse range of options for someone researching dishwashers available in the U.S. in 2024, from various price points and brands to features prioritizing performance or convenience. However, for a comprehensive decision, one might need to read the full reviews and cross-reference between these sources, especially noticing any models that are consistently highly rated.
#
# ####[FUNCTION RESULT] Appending tool output array...
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: requires_action
# Run requires action 1
#
# #### Submitting tool outputs for thread_id: thread_A0leTZTUdMbn6AUE0KsXXS5u, run_id: run_eKpg1x5WlFHVlEfxLlSVkqw3, tools_to_call: [RequiredActionFunctionToolCall(id='call_xWBHjEH8broZHjtAnIgDs3Wa', function=Function(arguments='{"user_request":"dishwasher comparison table 2024"}', name='perform_bing_search'), type='function')]
#
# ####[FUNCTION CALL #1] perform_bing_search()...
#
# ### Generating a search_query for bing based on this user request: dishwasher comparison table 2024
#
# ### Bing search query: {
#   "id": "chatcmpl-8icUJLgzh265SRi3Rkh1HhEtUdB68",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "message": {
#         "content": "\"Best dishwasher comparison chart 2024\"",
#         "role": "assistant",
#         "function_call": null,
#         "tool_calls": null
#       },
#       "logprobs": null
#     }
#   ],
#   "created": 1705645071,
#   "model": "gpt-4-1106-preview",
#   "object": "chat.completion",
#   "system_fingerprint": "fp_04de91a479",
#   "usage": {
#     "completion_tokens": 9,
#     "prompt_tokens": 25,
#     "total_tokens": 34
#   }
# }. Now executing the search...
# Title: Best dishwashers in 2024 | Tom's Guide
# URL: https://www.tomsguide.com/us/best-dishwashers,review-6292.html
# Snippet: Best dishwashers in 2024 By Katie Mortram last updated 8 December 2023 The best dishwashers for every family size and budget. Comments (0) Jump to: Quick list Best overall Best value Best...
#
# Title: Best Dishwashers of 2024 - Consumer Reports
# URL: https://www.consumerreports.org/appliances/dishwashers/best-dishwashers-of-the-year-a6109623431/
#
#
# ####[FUNCTION RESULT] Appending tool output array...
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: in_progress
# Current run status: completed
#
# =========== ASSISTANT RESPONSE ==========
#
# assistant: The search results provided do not contain a direct comparison table for dishwashers in 2024. Usually, comparison tables are embedded within the articles and are not indexed separately by search engines, making them harder to find directly.
#
# However, the search results do include a link to the "Best Dishwashers of 2024" by "This Old House," which suggests a section labeled "Compare Top Dishwashers." This may indicate that within the article, there is a comparison table that users can consult.
#
# Here's a link to the article for you to check out: [6 Best Dishwashers (2024 Guide) - This Old House](https://www.thisoldhouse.com/home-finances/reviews/best-dishwasher)
#
# You may find a structured comparison of dishwashers there that includes different models along with their features, performance, and other relevant details.
#
# To actually view and provide a comparison table, access to the full articles would be necessary, which I currently do not have except for the links and summaries from the search results.
#
# For further assistance, I would advise checking out the article directly or using the search results provided to access the individual articles which may contain comparison tables or lists that can help in making an informed choice.
# assistant: I apologize for the confusion, but it seems that there has been an error with processing the search results into a comparison table. The search results provide links and summaries to various sources that discuss the best dishwashers in 2024, but to create a comparison table manually, I would need to extract specific product information from each source, which is not possible without direct access to the content of the articles.
#
# To assist you in obtaining a comparison table of specific dishwasher models for 2024, I will need to use a different approach. I will perform another Bing search to attempt to directly find a comparison table that has already been created by one of these reputable sources. Please hold on for a moment.
# assistant: Unfortunately, the current search results don't directly provide a comparative table or structured comparison between different products. Each source listed in the search results reviews and ranks dishwashers based on their own criteria, which includes testing, features, value for money, and more. To obtain a comparison of products, further analysis and synthesis of these sources' content would be needed.
#
# For a detailed product comparison, one would have to visit each website individually, compare the top dishwashers recommended by each source, and collate the information into a comparative format, taking note of any overlap or consensus between the lists. This would provide insight into which dishwasher models are consistently rated highly across different sources.
#
# If you would like, I can attempt to provide a more structured product comparison by visiting each site and compiling the information into a coherent table. However, this would be a manually intensive task requiring more in-depth review of each source's content. Let me know if you wish to proceed with this or have any other specific requests!
# assistant: Here is a summary of the search results for the best dishwashers in the US for the year 2024:
#
# 1. Tom's Guide published an article listing the best dishwashers for every family size and budget.
# 2. Consumer Reports highlighted standouts from their testing, including models from Bosch, Ikea, and other top brands.
# 3. The New York Times' Wirecutter has a review for the best dishwashers but notes that their top pick, the Bosch 300 Series SHEM63W55N, has been discontinued and replaced.
# 4. Forbes Vetted provides a list of what they consider today's best dishwashers that can lift food residue from your dinnerware.
# 5. Reviewed named the Bosch 800 Series SHP78CM5N as the Best Overall dishwasher.
# 6. Good Housekeeping tested and reviewed the 6 best dishwashers of 2024, emphasizing ease of use.
# 7. CNET offers their top picks for the best dishwashers of 2024, categorizing them by deepest value to modern and best upgrade.
# 8. The Spruce mentions the GE GPT225SSLSS 24 in. Portable Dishwasher as the Best Portable pick.
#
# For details on specific dishwasher models and their features, you may want to click through to these articles. If you need a comparison or more specific information, let me know!
# Your request:  exit
# Exiting conversation
